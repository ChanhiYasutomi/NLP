# %% [markdown]
# ◆参考
#
# 自然言語処理100本ノック：https://nlp100.github.io/ja/ch01.html
#
# 答え：https://github.com/yamaru12345/nlp100

# %% [markdown]
# # 第2章: UNIXコマンド
# popular-names.txtは，アメリカで生まれた赤ちゃんの「名前」「性別」「人数」「年」をタブ区切り形式で格納したファイルである．以下の処理を行うプログラムを作成し，popular-names.txtを入力ファイルとして実行せよ．さらに，同様の処理をUNIXコマンドでも実行し，プログラムの実行結果を確認せよ．

# %%
# !wget https://nlp100.github.io/data/popular-names.txt
# Out:
# --2024-01-23 06:13:42--  https://nlp100.github.io/data/popular-names.txt
# Resolving nlp100.github.io (nlp100.github.io)... 185.199.108.153, 185.199.109.153, 185.199.110.153, ...
# Connecting to nlp100.github.io (nlp100.github.io)|185.199.108.153|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 55026 (54K) [text/plain]
# Saving to: ‘popular-names.txt.1’
#
# popular-names.txt.1 100%[===================>]  53.74K  --.-KB/s    in 0.01s
#
# 2024-01-23 06:13:42 (4.77 MB/s) - ‘popular-names.txt.1’ saved [55026/55026]

# %% [markdown]
# ## 10. 行数のカウント
# ***
# 行数をカウントせよ．確認にはwcコマンドを用いよ．

# %%
import pandas as pd

df = pd.read_table('./popular-names.txt', header=None, sep='\t', names=['name', 'sex', 'number', 'year'])
df_test = pd.read_table('./popular-names.txt', sep='\t')
df_test_2 = pd.read_table('./popular-names.txt', header=None, sep='\t')
df_test_3 = pd.read_table('./popular-names.txt', sep='\t', names=['name', 'sex', 'number', 'year'])

display(df.head())
display(df_test.head())
display(df_test_2.head())
display(df_test_3.head())
print(len(df))
# Out:
#         name sex  number  year
# 0       Mary   F    7065  1880
# 1       Anna   F    2604  1880
# 2       Emma   F    2003  1880
# 3  Elizabeth   F    1939  1880
# 4     Minnie   F    1746  1880
#         Mary  F  7065  1880
# 0       Anna  F  2604  1880
# 1       Emma  F  2003  1880
# 2  Elizabeth  F  1939  1880
# 3     Minnie  F  1746  1880
# 4   Margaret  F  1578  1880
#            0  1     2     3
# 0       Mary  F  7065  1880
# 1       Anna  F  2604  1880
# 2       Emma  F  2003  1880
# 3  Elizabeth  F  1939  1880
# 4     Minnie  F  1746  1880
#         name sex  number  year
# 0       Mary   F    7065  1880
# 1       Anna   F    2604  1880
# 2       Emma   F    2003  1880
# 3  Elizabeth   F    1939  1880
# 4     Minnie   F    1746  1880
# 2780

# %%
# 確認
# !wc -l ./popular-names.txt
# Out:
# 2780 ./popular-names.txt

# %% [markdown]
# ## 11. タブをスペースに置換
# ***
# タブ1文字につきスペース1文字に置換せよ．確認にはsedコマンド，trコマンド，もしくはexpandコマンドを用いよ．

# %%
# 確認
# !sed -e 's/\t/ /g' ./popular-names.txt | head -n 5
# Out:
# Mary F 7065 1880
# Anna F 2604 1880
# Emma F 2003 1880
# Elizabeth F 1939 1880
# Minnie F 1746 1880

# %% [markdown]
# ## 12. 1列目をcol1.txtに，2列目をcol2.txtに保存
# ***
# 各行の1列目だけを抜き出したものをcol1.txtに，2列目だけを抜き出したものをcol2.txtとしてファイルに保存せよ．確認にはcutコマンドを用いよ．

# %%
col1 = df['name']
col1.to_csv('./col1.txt', index=False)
print(col1.head())
# Out:
# 0         Mary
# 1         Anna
# 2         Emma
# 3    Elizabeth
# 4       Minnie
# Name: name, dtype: object

# %%
# 確認
# !cut -f 1 ./popular-names.txt > ./col1_chk.txt
# !cat ./col1_chk.txt | head -n 5
# Out:
# Mary
# Anna
# Emma
# Elizabeth
# Minnie

# %%
col2 = df['sex']
col2.to_csv('./col2.txt', index=False)
print(col2.head())
# Out:
# 0    F
# 1    F
# 2    F
# 3    F
# 4    F
# Name: sex, dtype: object

# %%
# !cut -f 2 ./popular-names.txt > ./col2_chk.txt
# !cat ./col2_chk.txt | head -n 5
# Out:
# F
# F
# F
# F
# F

# %% [markdown]
# ## 13. col1.txtとcol2.txtをマージ
# ***
# 12で作ったcol1.txtとcol2.txtを結合し，元のファイルの1列目と2列目をタブ区切りで並べたテキストファイルを作成せよ．確認にはpasteコマンドを用いよ．

# %%
col1 = pd.read_table('./col1.txt')
col2 = pd.read_table('./col2.txt')
merged_1_2 = pd.concat([col1, col2], axis=1)
merged_1_2.to_csv('./merged_1_2.txt', sep='\t', index=False)
print(merged_1_2.head())
# Out:
#         name sex
# 0       Mary   F
# 1       Anna   F
# 2       Emma   F
# 3  Elizabeth   F
# 4     Minnie   F

# %%
# 確認
# !paste ./col1_chk.txt ./col2_chk.txt | head -n 5
# Out:
# Mary	F
# Anna	F
# Emma	F
# Elizabeth	F
# Minnie	F

# %% [markdown]
# ## 14. 先頭からN行を出力
# ***
# 自然数Nをコマンドライン引数などの手段で受け取り，入力のうち先頭のN行だけを表示せよ．確認にはheadコマンドを用いよ．

# %%
def output_head(N):
  print(df.head(N))
output_head(5)
# Out:
#         name sex  number  year
# 0       Mary   F    7065  1880
# 1       Anna   F    2604  1880
# 2       Emma   F    2003  1880
# 3  Elizabeth   F    1939  1880
# 4     Minnie   F    1746  1880

# %%
# 確認
# !head -n 5 ./popular-names.txt
# Out:
# Mary	F	7065	1880
# Anna	F	2604	1880
# Emma	F	2003	1880
# Elizabeth	F	1939	1880
# Minnie	F	1746	1880

# %% [markdown]
# ## 15. 末尾のN行を出力
# ***
# 自然数Nをコマンドライン引数などの手段で受け取り，入力のうち末尾のN行だけを表示せよ．確認にはtailコマンドを用いよ．

# %%
def output_tail(N):
  print(df.tail(N))
output_tail(5)
# Out:
#           name sex  number  year
# 2775  Benjamin   M   13381  2018
# 2776    Elijah   M   12886  2018
# 2777     Lucas   M   12585  2018
# 2778     Mason   M   12435  2018
# 2779     Logan   M   12352  2018

# %%
# 確認
# !tail -n 5 ./popular-names.txt
# Out:
# Benjamin	M	13381	2018
# Elijah	M	12886	2018
# Lucas	M	12585	2018
# Mason	M	12435	2018
# Logan	M	12352	2018

# %% [markdown]
# ## 16. ファイルをN分割する
# ***
# 自然数Nをコマンドライン引数などの手段で受け取り，入力のファイルを行単位でN分割せよ．同様の処理をsplitコマンドで実現せよ．

# %%
def split_file(N):
  tmp = df.reset_index(drop=False)
  df_cut = pd.qcut(tmp.index, N, labels=[i for i in range(N)])
  df_cut = pd.concat([df, pd.Series(df_cut, name='sp')], axis=1)

  return df_cut

df_cut = split_file(10)
display(df_cut['sp'].value_counts())
display(df_cut.head())
# Out:
# 0    278
# 1    278
# 2    278
# 3    278
# 4    278
# 5    278
# 6    278
# 7    278
# 8    278
# 9    278
# Name: sp, dtype: int64
#         name sex  number  year sp
# 0       Mary   F    7065  1880  0
# 1       Anna   F    2604  1880  0
# 2       Emma   F    2003  1880  0
# 3  Elizabeth   F    1939  1880  0
# 4     Minnie   F    1746  1880  0

# %%
display(df.reset_index().head())
display(df.reset_index(drop=False).head())
# Out:
#    index       name sex  number  year
# 0      0       Mary   F    7065  1880
# 1      1       Anna   F    2604  1880
# 2      2       Emma   F    2003  1880
# 3      3  Elizabeth   F    1939  1880
# 4      4     Minnie   F    1746  1880
#    index       name sex  number  year
# 0      0       Mary   F    7065  1880
# 1      1       Anna   F    2604  1880
# 2      2       Emma   F    2003  1880
# 3      3  Elizabeth   F    1939  1880
# 4      4     Minnie   F    1746  1880

# %%
# !split -l 200 -d ./popular-names.txt sp

# %% [markdown]
# ## 17. １列目の文字列の異なり
# ***
# 1列目の文字列の種類（異なる文字列の集合）を求めよ．確認にはcut, sort, uniqコマンドを用いよ．

# %%
display(df.drop_duplicates(subset='name'))
print(len(df.drop_duplicates(subset='name')))
# Out:
#            name sex  number  year
# 0          Mary   F    7065  1880
# 1          Anna   F    2604  1880
# 2          Emma   F    2003  1880
# 3     Elizabeth   F    1939  1880
# 4        Minnie   F    1746  1880
# ...         ...  ..     ...   ...
# 2738     Elijah   M   13902  2016
# 2747     Amelia   F   11833  2017
# 2754      Logan   M   14014  2017
# 2758     Oliver   M   13193  2017
# 2777      Lucas   M   12585  2018
#
# [136 rows x 4 columns]
# 136

# %%
# 確認
# !cut -f 1 ./popular-names.txt | sort | uniq | wc -l
# Out:
# 136

# %% [markdown]
# ## 18. 各行を3コラム目の数値の降順にソート
# ***
# 各行を3コラム目の数値の逆順で整列せよ（注意: 各行の内容は変更せずに並び替えよ）．確認にはsortコマンドを用いよ（この問題はコマンドで実行した時の結果と合わなくてもよい）．

# %%
df.sort_values(by='number', ascending=False, inplace=True)
display(df.head())
# Out:
#          name sex  number  year
# 1340    Linda   F   99689  1947
# 1360    Linda   F   96211  1948
# 1350    James   M   94757  1947
# 1550  Michael   M   92704  1957
# 1351   Robert   M   91640  1947

# %%
# 確認
# !cat ./popular-names.txt | sort -rnk 3 | head -n 5
# Out:
# Linda	F	99689	1947
# Linda	F	96211	1948
# James	M	94757	1947
# Michael	M	92704	1957
# Robert	M	91640	1947

# %% [markdown]
# ## 19. 各行の1コラム目の文字列の出現頻度を求め，出現頻度の高い順に並べる
# ***
# 各行の1列目の文字列の出現頻度を求め，その高い順に並べて表示せよ．確認にはcut, uniq, sortコマンドを用いよ．

# %%
display(df['name'].value_counts())
# Out:
# James      118
# William    111
# Robert     108
# John       108
# Mary        92
#           ...
# Julie        1
# Laura        1
# Walter       1
# Lori         1
# Rachel       1
# Name: name, Length: 136, dtype: int64

# %%
# 確認
# !cut -f 1 ./popular-names.txt | sort | uniq -c | sort -rn | head -n 5
# Out:
#     118 James
#     111 William
#     108 Robert
#     108 John
#      92 Mary
